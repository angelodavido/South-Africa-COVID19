# %% [markdown]
# https://www.youtube.com/watch?v=uKb9fA4gyWQ

# %% [markdown]
# https://www.worthwebscraping.com/scraping-news-websites-like-cnn-nbc-using-python/

# %%
import pandas as pd
import re
import seaborn as sns

# %%
with open("newsZA.txt",encoding="utf8") as f:
    contents = f.read()
    print(contents)
# Out:
# BusinessTechThe National Institute for Communicable Diseases (NICD) has reported 16,055 new Covid-19 cases in South Africa, taking the total number of laboratory-confirmed cases to 3,004,203.This increase represents a 24.3% positivity rate, it said.As per the National Department of Health, a further 25 Covid-19 related deaths have been reported, taking total fatalities to 89,944 to date.The majority of new cases are from Gauteng (72%). Western Cape and KwaZulu-Natal each accounted for 6% and the North West 5%.#COVID19 UPDATE: A total of 65,990 tests were conducted in the last 24hrs, with 16,055 new cases, which represents a 24.3% positivity rate. A further 25 #COVID19 related deaths have been reported, bringing total fatalities to 89,994 to date. See more here: https://t.co/PzzZEUQzNl pic.twitter.com/1qn1apRkri— NICD (@nicd_sa) December 3, 2021The fourth wave has sparked an increase in hospital admissions in children under the age of five, the NICD said.In a briefing led by health mi
# ...

# %%
type(contents)
# Out:
# str

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Initialize VADER so we can use it later
sentimentAnalyser = SentimentIntensityAnalyzer()

# %%
sentimentAnalyser.polarity_scores(contents)
# Out:
# {'neg': 0.067, 'neu': 0.855, 'pos': 0.078, 'compound': 1.0}

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# Start with one review:
text = contents

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=60, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
import nltk
from nltk.corpus import stopwords
set(stopwords.words('english'))
sw_nltk = stopwords.words('english')

# %%
words = [word for word in contents.split() if word.lower() not in sw_nltk]
new_text = " ".join(words)
print(new_text)
print("Old length: ", len(text))
print("New length: ", len(new_text))
# Out:
# BusinessTechThe National Institute Communicable Diseases (NICD) reported 16,055 new Covid-19 cases South Africa, taking total number laboratory-confirmed cases 3,004,203.This increase represents 24.3% positivity rate, said.As per National Department Health, 25 Covid-19 related deaths reported, taking total fatalities 89,944 date.The majority new cases Gauteng (72%). Western Cape KwaZulu-Natal accounted 6% North West 5%.#COVID19 UPDATE: total 65,990 tests conducted last 24hrs, 16,055 new cases, represents 24.3% positivity rate. 25 #COVID19 related deaths reported, bringing total fatalities 89,994 date. See here: https://t.co/PzzZEUQzNl pic.twitter.com/1qn1apRkri— NICD (@nicd_sa) December 3, 2021The fourth wave sparked increase hospital admissions children age five, NICD said.In briefing led health minister, Dr Joe Phaahla, NICD’s Dr Waasila Jassat said rise children hospital Covid-19 public private sectors.While hospital admissions initially recorded Tshwane, Jassat said starting see 
# ...

# %%
new_text
# Out:
# 'BusinessTechThe National Institute Communicable Diseases (NICD) reported 16,055 new Covid-19 cases South Africa, taking total number laboratory-confirmed cases 3,004,203.This increase represents 24.3% positivity rate, said.As per National Department Health, 25 Covid-19 related deaths reported, taking total fatalities 89,944 date.The majority new cases Gauteng (72%). Western Cape KwaZulu-Natal accounted 6% North West 5%.#COVID19 UPDATE: total 65,990 tests conducted last 24hrs, 16,055 new cases, represents 24.3% positivity rate. 25 #COVID19 related deaths reported, bringing total fatalities 89,994 date. See here: https://t.co/PzzZEUQzNl pic.twitter.com/1qn1apRkri— NICD (@nicd_sa) December 3, 2021The fourth wave sparked increase hospital admissions children age five, NICD said.In briefing led health minister, Dr Joe Phaahla, NICD’s Dr Waasila Jassat said rise children hospital Covid-19 public private sectors.While hospital admissions initially recorded Tshwane, Jassat said starting see
# ...

# %%
# Define a function to clean the text
def clean(text):
# Removes all special characters and numericals leaving the alphabets
    text = re.sub('[^A-Za-z]+', ' ', text)
    return text

# %%
new_text_clean = clean(new_text)

# %%
new_text_clean
# Out:
# 'BusinessTechThe National Institute Communicable Diseases NICD reported new Covid cases South Africa taking total number laboratory confirmed cases This increase represents positivity rate said As per National Department Health Covid related deaths reported taking total fatalities date The majority new cases Gauteng Western Cape KwaZulu Natal accounted North West COVID UPDATE total tests conducted last hrs new cases represents positivity rate COVID related deaths reported bringing total fatalities date See here https t co PzzZEUQzNl pic twitter com qn apRkri NICD nicd sa December The fourth wave sparked increase hospital admissions children age five NICD said In briefing led health minister Dr Joe Phaahla NICD s Dr Waasila Jassat said rise children hospital Covid public private sectors While hospital admissions initially recorded Tshwane Jassat said starting see increase Gauteng districts well The week week cases admissions higher we ve seen before told media While children may heavi
# ...

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=60, max_words=100, background_color="white").generate(new_text_clean)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
#Word cloud
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

wordcloud = WordCloud(
                          background_color='white',
                         
                          max_words=100,
                          max_font_size=50, 
                          random_state=42
                         ).generate(new_text_clean)
print(wordcloud)
fig = plt.figure(1)
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
fig.savefig("word1.png", dpi=900)

# %%
from textblob import TextBlob

# %% [markdown]
# ### Look for sentiments

# %%
nltk.sent_tokenize(text)
# Out:
# ['BusinessTechThe National Institute for Communicable Diseases (NICD) has reported 16,055 new Covid-19 cases in South Africa, taking the total number of laboratory-confirmed cases to 3,004,203.This increase represents a 24.3% positivity rate, it said.As per the National Department of Health, a further 25 Covid-19 related deaths have been reported, taking total fatalities to 89,944 to date.The majority of new cases are from Gauteng (72%).',
#  'Western Cape and KwaZulu-Natal each accounted for 6% and the North West 5%.#COVID19 UPDATE: A total of 65,990 tests were conducted in the last 24hrs, with 16,055 new cases, which represents a 24.3% positivity rate.',
#  'A further 25 #COVID19 related deaths have been reported, bringing total fatalities to 89,994 to date.',
# ...

# %%
for number, sentence in enumerate(nltk.sent_tokenize(text)):
    print(number, sentence)
# Out:
# 0 BusinessTechThe National Institute for Communicable Diseases (NICD) has reported 16,055 new Covid-19 cases in South Africa, taking the total number of laboratory-confirmed cases to 3,004,203.This increase represents a 24.3% positivity rate, it said.As per the National Department of Health, a further 25 Covid-19 related deaths have been reported, taking total fatalities to 89,944 to date.The majority of new cases are from Gauteng (72%).
# 1 Western Cape and KwaZulu-Natal each accounted for 6% and the North West 5%.#COVID19 UPDATE: A total of 65,990 tests were conducted in the last 24hrs, with 16,055 new cases, which represents a 24.3% positivity rate.
# 2 A further 25 #COVID19 related deaths have been reported, bringing total fatalities to 89,994 to date.
# ...

# %%
# Break text into sentences
sentences = nltk.sent_tokenize(text)

# Make empty list
sentence_scores = []
# Get each sentence and sentence number, which is what enumerate does
for number, sentence in enumerate(sentences):
    # Use VADER to calculate sentiment
    scores = sentimentAnalyser.polarity_scores(sentence)
    # Make dictionary and append it to the previously empty list
    sentence_scores.append({'sentence': sentence, 'sentence_number': number+1, 'sentiment_score': scores['compound']})

# %%
pd.DataFrame(sentence_scores)
# Out:
#                                                sentence  sentence_number  \
# 0     BusinessTechThe National Institute for Communi...                1
# 1     Western Cape and KwaZulu-Natal each accounted ...                2
# 2     A further 25 #COVID19 related deaths have been...                3
# 3     See more here: https://t.co/PzzZEUQzNl pic.twi...                4
# 4     The trend that we see now is different to what...                5
# ...                                                 ...              ...
# 1478  We try to get to patients on time but unfortun...             1479
# 1479  More transmission means more serious illness a...             1480
# 1480  “While supply challenges grind on, dose-sharin...             1481
# 1481  We are grateful for the pledges made by our in...             1482
# 1482  Africa must not be left languishing in the thr...             1483
#
#       sentiment_score
# 0              0.2500
# 1              0.5106
# ...

# %%
# Assign DataFrame to variable red_df
red_df = pd.DataFrame(sentence_scores)

# Sort by the column "sentiment_score" and slice for first 10 values
red_df.sort_values(by='sentiment_score')[:-5]
# Out:
#                                                sentence  sentence_number  \
# 1302  ""The right to protest is very important in ou...             1303
# 603   CAPE TOWN - The Beer Association of South Afri...              604
# 1465  Dozens more have less than half remaining.Mala...             1466
# 1478  We try to get to patients on time but unfortun...             1479
# 1459  The health minister has been suspended pending...             1460
# ...                                                 ...              ...
# 840   Material may not be published or reproduced in...              841
# 1064  The PIN can then be entered to access the fina...             1065
# 1153  “Vaccinate to protect your friends, families, ...             1154
# 959   However, this is up a percentage point compare...              960
# 162   “Ultimately, employers should guard against to...              163
#
#       sentiment_score
# 1302          -0.9910
# 603           -0.9810
# ...

# %%
# making a bool series
bool_series = red_df["sentiment_score"].between(-1,0, inclusive = True)
# returning dataframe with sentiment_score between above values
red_df[bool_series]
# Out:
#                                                sentence  sentence_number  \
# 2     A further 25 #COVID19 related deaths have been...                3
# 7     Eyder Peralta\n    \nSouth Africa's health min...                8
# 8     Every major city is seeing a rise in cases, an...                9
# 9     NPR's Eyder Peralta is in Cape Town, South Afr...               10
# 11    And in terms of numbers, on November 16, the s...               12
# ...                                                 ...              ...
# 1476                             That’s the difference.             1477
# 1477                            We see death happening.             1478
# 1478  We try to get to patients on time but unfortun...             1479
# 1479  More transmission means more serious illness a...             1480
# 1482  Africa must not be left languishing in the thr...             1483
#
#       sentiment_score
# 2             -0.6361
# 7              0.0000
# ...

# %% [markdown]
# https://github.com/Shwetago/Sentiment_Analysis/blob/master/Twitter_Sentiment_Analysis.ipynb

# %% [markdown]
# https://www.geeksforgeeks.org/python-pandas-series-between/

# %% [markdown]
# https://www.analyticsvidhya.com/blog/2021/06/sentiment-analysis-using-nltk-a-practical-approach/

# %%
a=[]
for i in red_df['sentiment_score']:
    if i <0:                              
        a.append(0)
    if i==0:
        a.append(1)
    if i>0:
        a.append(2)

# %%
sns.countplot(a)
plt.xlabel('news', color = 'red')
plt.ylabel('Count', color = 'red')
plt.xticks([0,1,2],['Negative','Neutral','Positive'])
plt.title('COUNT PLOT', color = 'r')
plt.show()
# Out:
# C:\Users\mwamb\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Generate result using pandas
# result = []
# for value in df["Marks"]:
#     if value >= 33:
#         result.append("Pass")
#     elif value < 0 and value > 100:
#         result.append("Invalid")
#     else:
#         result.append("Fail")
       
# df["Result"] = result   
# print(df)


sentiment=[]
for i in red_df['sentiment_score']:
    if i <0:                              
        sentiment.append(-1)
    if i==0:
        sentiment.append(0)
    if i>0:
        sentiment.append(1)

red_df['Sentiment'] = sentiment
red_df.head(10)
# Out:
#                                             sentence  sentence_number  \
# 0  BusinessTechThe National Institute for Communi...                1
# 1  Western Cape and KwaZulu-Natal each accounted ...                2
# 2  A further 25 #COVID19 related deaths have been...                3
# 3  See more here: https://t.co/PzzZEUQzNl pic.twi...                4
# 4  The trend that we see now is different to what...                5
# 5  And that the younger children less than 12 who...                6
# 6  For more information you can review our Terms ...                7
# 7  Eyder Peralta\n    \nSouth Africa's health min...                8
# 8  Every major city is seeing a rise in cases, an...                9
# 9  NPR's Eyder Peralta is in Cape Town, South Afr...               10
#
#    sentiment_score  Sentiment
# 0           0.2500          1
# 1           0.5106          1
# 2          -0.6361         -1
# 3           0.5112          1
# 4           0.2247          1
# ...
